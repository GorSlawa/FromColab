# %% [markdown]
# <a href="https://colab.research.google.com/github/GorSlawa/FromColab/blob/main/WORKFLOW2PNG_Add_Workflow_to_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)

# %% [markdown]
# # <font size="7"><font color="#aa9f4c">WORKFLOW</font>2<font color="#4e7bbf">PNG</font></font>
# Add workflow json dictionaries to PNG images to use as workflow imports in [ComfyUI](https://github.com/comfyanonymous/ComfyUI)
#
# <font size="2">Created by WAS#0263</font>

# %%
#@title Add Workflow to PNG


from PIL import Image, PngImagePlugin
import os

def make_workflow_png(image_path, workflow_path):
    if not os.path.exists(image_path):
        ValueError(f"Invalid image path `{image_path}`")
    if not os.path.exists(workflow_path):
        ValueError(f"Invalid workflow path `{workflow_path}`")
    path = os.path.dirname(image_path)
    filename = os.path.basename(image_path).rsplit('.', 1)[0]
    try:
        with open(workflow_path, "r") as file:
            data = file.read()
    except OSError as e:
        Exception("There was an error reading the workflow JSON:", e)
    image = Image.open(image_path)
    info = PngImagePlugin.PngInfo()
    info.add_text("workflow", data)
    new_path = os.path.join(path, filename+'_workflow.png')
    image.save(new_path, "PNG", pnginfo=info)
    return new_path

# Create the workflow PNG

image = '/content/ipadapter_style_composition.png' #@param {type:"string"}
workflow = '/content/ipadapter_style_composition.json' #@param {type:"string"}

workflow_png_path = make_workflow_png(image, workflow)

img = Image.open(image)

print("Workflow added to image:", workflow_png_path)
# Out:
# Workflow added to image: /content/ipadapter_style_composition_workflow.png

# %% [markdown]
# # Optional Python Script
#
# A CLI script for adding a workflow to a PNG file. **Requres Pillow module (PIL).**
#
# ```python
# import argparse
# import os
# from PIL import Image, PngImagePlugin
#
# def make_workflow_png(image_path, workflow_path):
#     if not os.path.exists(image_path):
#         ValueError(f"Invalid image path `{image_path}`")
#     if not os.path.exists(workflow_path):
#         ValueError(f"Invalid workflow path `{workflow_path}`")
#     path = os.path.dirname(image_path)
#     filename = os.path.basename(image_path).rsplit('.', 1)[0]
#     try:
#         with open(workflow_path, "r") as file:
#             data = file.read()
#     except OSError as e:
#         Exception("There was an error reading the workflow JSON:", e)
#     image = Image.open(image_path)
#     info = PngImagePlugin.PngInfo()
#     info.add_text("workflow", data)
#     new_path = os.path.join(path, filename+'.png')
#     image.save(new_path, "PNG", pnginfo=info)
#     return new_path
#
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Add workflow metadata to a PNG image")
#     parser.add_argument("--image_path", type=str, help="Path to the PNG image")
#     parser.add_argument("--workflow_path", type=str, help="Path to the workflow JSON file")
#     args = parser.parse_args()
#     new_image_path = make_workflow_png(args.image_path, args.workflow_path)
#
#     print(f"Workflow added to `{new_image_path}`")
# ```
#
#
# ## Usage
#
# Open command prompt or terminal and CD to the location of the script, then run
#
# ```python
# python workflow2png.py --image_path "/path/to/image.png" --workflow_path "/path/to/workflow.json"
# ```
#
# ### Verification
#
# You can verify the image data by trying to open the image as a workflow with ComfyUI, or try the code below:
#
# ```python
# img = Image.open('/path/to/image.png')
# print('Workflow Added:', img.text['workflow'])
# ```

# %%
#@title Check workflow
path = '/content/Comparison_Workflow.png' #@param {type:"string"}
from PIL import Image
img = Image.open(path)
print('Workflow Added:', img.text['workflow'])
# Out:
# Workflow Added: {
#   "last_node_id": 49,
#   "last_link_id": 111,
#   "nodes": [
#     {
#       "id": 14,
#       "type": "KSampler",
#       "pos": [
#         873,
#         -333
#       ],
#       "size": {
#         "0": 315,
#         "1": 474
#       },
#       "flags": {},
#       "order": 9,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "model",
#           "type": "MODEL",
#           "link": 22
#         },
#         {
#           "name": "positive",
#           "type": "CONDITIONING",
#           "link": 20
#         },
#         {
#           "name": "negative",
#           "type": "CONDITIONING",
#           "link": 21
#         },
#         {
#           "name": "latent_image",
#           "type": "LATENT",
#           "link": 19
#         },
#         {
#           "name": "seed",
#           "type": "INT",
#           "link": 31,
#           "widget": {
#             "name": "seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             23
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "title": "Vanilla Noise KSampler",
#       "properties": {
#         "Node name for S&R": "KSampler"
#       },
#       "widgets_values": [
#         135313577566690,
#         "fixed",
#         20,
#         8,
#         "dpmpp_3m_sde",
#         "karras",
#         1
#       ],
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 15,
#       "type": "EmptyLatentImage",
#       "pos": [
#         22,
#         727
#       ],
#       "size": {
#         "0": 315,
#         "1": 106
#       },
#       "flags": {},
#       "order": 0,
#       "mode": 0,
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             19
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "EmptyLatentImage"
#       },
#       "widgets_values": [
#         1024,
#         1024,
#         1
#       ]
#     },
#     {
#       "id": 16,
#       "type": "VAEDecode",
#       "pos": [
#         1209,
#         -332
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 12,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "samples",
#           "type": "LATENT",
#           "link": 23
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 24
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             25,
#             63
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEDecode"
#       },
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 33,
#       "type": "Image Resize",
#       "pos": [
#         2095,
#         -221
#       ],
#       "size": {
#         "0": 315,
#         "1": 178
#       },
#       "flags": {},
#       "order": 21,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "image",
#           "type": "IMAGE",
#           "link": 85
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             65
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "Image Resize"
#       },
#       "widgets_values": [
#         "rescale",
#         "true",
#         "lanczos",
#         0.5,
#         1024,
#         1536
#       ],
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 36,
#       "type": "Image Resize",
#       "pos": [
#         2095,
#         430
#       ],
#       "size": {
#         "0": 315,
#         "1": 178
#       },
#       "flags": {},
#       "order": 20,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "image",
#           "type": "IMAGE",
#           "link": 86
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             68
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "Image Resize"
#       },
#       "widgets_values": [
#         "rescale",
#         "true",
#         "lanczos",
#         0.5,
#         1024,
#         1536
#       ],
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 39,
#       "type": "Image Resize",
#       "pos": [
#         2095,
#         1090
#       ],
#       "size": {
#         "0": 315,
#         "1": 178
#       },
#       "flags": {},
#       "order": 22,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "image",
#           "type": "IMAGE",
#           "link": 87
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             69
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "Image Resize"
#       },
#       "widgets_values": [
#         "rescale",
#         "true",
#         "lanczos",
#         0.5,
#         1024,
#         1536
#       ],
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 8,
#       "type": "VAEDecode",
#       "pos": [
#         1209,
#         189
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 11,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "samples",
#           "type": "LATENT",
#           "link": 18
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 8
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             9,
#             70
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEDecode"
#       },
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 23,
#       "type": "VAEDecode",
#       "pos": [
#         1216,
#         790
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 13,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "samples",
#           "type": "LATENT",
#           "link": 37
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 38
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             39,
#             71
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEDecode"
#       },
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 32,
#       "type": "UpscaleModelLoader",
#       "pos": [
#         28,
#         245
#       ],
#       "size": {
#         "0": 315,
#         "1": 58
#       },
#       "flags": {},
#       "order": 1,
#       "mode": 0,
#       "outputs": [
#         {
#           "name": "UPSCALE_MODEL",
#           "type": "UPSCALE_MODEL",
#           "links": [
#             64,
#             72,
#             73
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "UpscaleModelLoader"
#       },
#       "widgets_values": [
#         "4x-UltraMix_Balanced.pth"
#       ]
#     },
#     {
#       "id": 42,
#       "type": "SaveImage",
#       "pos": [
#         3620,
#         -330
#       ],
#       "size": {
#         "0": 570,
#         "1": 610
#       },
#       "flags": {},
#       "order": 33,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 76
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         "ComfyUI"
#       ],
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 6,
#       "type": "CLIPTextEncode",
#       "pos": [
#         415,
#         189
#       ],
#       "size": {
#         "0": 422.84503173828125,
#         "1": 164.31304931640625
#       },
#       "flags": {},
#       "order": 5,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "clip",
#           "type": "CLIP",
#           "link": 3
#         }
#       ],
#       "outputs": [
#         {
#           "name": "CONDITIONING",
#           "type": "CONDITIONING",
#           "links": [
#             15,
#             20,
#             32,
#             51,
#             53,
#             82
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "CLIPTextEncode"
#       },
#       "widgets_values": [
#         "photo, 8k portrait of beautiful chinese warrior with brown hair, shining armor 明光甲 chain-mail, elegant, highly detailed, majestic, art by Ilya Kuvshinov, ebony feather filigree, broken glass, (masterpiece, finely detailed beautiful eyes:1.2), \n\nhdr, realistic, high definition, (sharp, crisp, high pass, high frequency:1.125)"
#       ],
#       "color": "#432",
#       "bgcolor": "#653"
#     },
#     {
#       "id": 7,
#       "type": "CLIPTextEncode",
#       "pos": [
#         413,
#         389
#       ],
#       "size": {
#         "0": 425.27801513671875,
#         "1": 180.6060791015625
#       },
#       "flags": {},
#       "order": 6,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "clip",
#           "type": "CLIP",
#           "link": 5
#         }
#       ],
#       "outputs": [
#         {
#           "name": "CONDITIONING",
#           "type": "CONDITIONING",
#           "links": [
#             16,
#             21,
#             33,
#             54,
#             56,
#             83
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "CLIPTextEncode"
#       },
#       "widgets_values": [
#         "empty background, plain, dof, depth of field, cartoon, drawing, sketch, line-art,\n\nteeth, smiling, wide eyes"
#       ],
#       "color": "#432",
#       "bgcolor": "#653"
#     },
#     {
#       "id": 31,
#       "type": "ImageUpscaleWithModel",
#       "pos": [
#         2095,
#         -330
#       ],
#       "size": {
#         "0": 241.79998779296875,
#         "1": 46
#       },
#       "flags": {},
#       "order": 17,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "upscale_model",
#           "type": "UPSCALE_MODEL",
#           "link": 64
#         },
#         {
#           "name": "image",
#           "type": "IMAGE",
#           "link": 63
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             85
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "ImageUpscaleWithModel"
#       },
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 35,
#       "type": "ImageUpscaleWithModel",
#       "pos": [
#         2095,
#         330
#       ],
#       "size": {
#         "0": 241.79998779296875,
#         "1": 46
#       },
#       "flags": {},
#       "order": 15,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "upscale_model",
#           "type": "UPSCALE_MODEL",
#           "link": 73
#         },
#         {
#           "name": "image",
#           "type": "IMAGE",
#           "link": 70
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             86
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "ImageUpscaleWithModel"
#       },
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 38,
#       "type": "ImageUpscaleWithModel",
#       "pos": [
#         2095,
#         990
#       ],
#       "size": {
#         "0": 241.79998779296875,
#         "1": 46
#       },
#       "flags": {},
#       "order": 19,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "upscale_model",
#           "type": "UPSCALE_MODEL",
#           "link": 72
#         },
#         {
#           "name": "image",
#           "type": "IMAGE",
#           "link": 71
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             87
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "ImageUpscaleWithModel"
#       },
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 37,
#       "type": "VAEEncode",
#       "pos": [
#         2200,
#         650
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 23,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "pixels",
#           "type": "IMAGE",
#           "link": 68
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 88
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             95
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEEncode"
#       },
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 40,
#       "type": "VAEEncode",
#       "pos": [
#         2200,
#         1310
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 25,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "pixels",
#           "type": "IMAGE",
#           "link": 69
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 89
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             97
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEEncode"
#       },
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 41,
#       "type": "SaveImage",
#       "pos": [
#         3623,
#         330
#       ],
#       "size": {
#         "0": 570,
#         "1": 610
#       },
#       "flags": {},
#       "order": 35,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 77
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         "ComfyUI"
#       ],
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 43,
#       "type": "SaveImage",
#       "pos": [
#         3623,
#         1021
#       ],
#       "size": {
#         "0": 570,
#         "1": 610
#       },
#       "flags": {},
#       "order": 36,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 78
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         "ComfyUI"
#       ],
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 22,
#       "type": "SaveImage",
#       "pos": [
#         1460,
#         1021
#       ],
#       "size": {
#         "0": 570,
#         "1": 610
#       },
#       "flags": {},
#       "order": 18,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 39
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         "ComfyUI"
#       ],
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 17,
#       "type": "SaveImage",
#       "pos": [
#         1470,
#         -330
#       ],
#       "size": {
#         "0": 570,
#         "1": 610
#       },
#       "flags": {},
#       "order": 16,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 25
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         "ComfyUI"
#       ],
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 25,
#       "type": "VAEDecode",
#       "pos": [
#         3380,
#         194
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 32,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "samples",
#           "type": "LATENT",
#           "link": 79
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 91
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             77
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEDecode"
#       },
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 30,
#       "type": "VAEDecode",
#       "pos": [
#         3380,
#         787
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 34,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "samples",
#           "type": "LATENT",
#           "link": 47
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 90
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             78
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEDecode"
#       },
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 28,
#       "type": "VAEDecode",
#       "pos": [
#         3380,
#         -333
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 30,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "samples",
#           "type": "LATENT",
#           "link": 45
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 92
#         }
#       ],
#       "outputs": [
#         {
#           "name": "IMAGE",
#           "type": "IMAGE",
#           "links": [
#             76
#           ],
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEDecode"
#       },
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 9,
#       "type": "SaveImage",
#       "pos": [
#         1467,
#         330
#       ],
#       "size": {
#         "0": 570,
#         "1": 610
#       },
#       "flags": {},
#       "order": 14,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 9
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         "ComfyUI"
#       ],
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 44,
#       "type": "KSampler",
#       "pos": [
#         3040,
#         194
#       ],
#       "size": {
#         "0": 315,
#         "1": 474
#       },
#       "flags": {
#         "pinned": true
#       },
#       "order": 29,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "model",
#           "type": "MODEL",
#           "link": 84
#         },
#         {
#           "name": "positive",
#           "type": "CONDITIONING",
#           "link": 82
#         },
#         {
#           "name": "negative",
#           "type": "CONDITIONING",
#           "link": 83
#         },
#         {
#           "name": "latent_image",
#           "type": "LATENT",
#           "link": 100
#         },
#         {
#           "name": "seed",
#           "type": "INT",
#           "link": 81,
#           "widget": {
#             "name": "seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             79
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "KSampler"
#       },
#       "widgets_values": [
#         135313577566690,
#         "fixed",
#         20,
#         8,
#         "dpmpp_3m_sde",
#         "karras",
#         0.5
#       ],
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 27,
#       "type": "KSampler",
#       "pos": [
#         3040,
#         -333
#       ],
#       "size": {
#         "0": 315,
#         "1": 474
#       },
#       "flags": {},
#       "order": 27,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "model",
#           "type": "MODEL",
#           "link": 48
#         },
#         {
#           "name": "positive",
#           "type": "CONDITIONING",
#           "link": 51
#         },
#         {
#           "name": "negative",
#           "type": "CONDITIONING",
#           "link": 56
#         },
#         {
#           "name": "latent_image",
#           "type": "LATENT",
#           "link": 102
#         },
#         {
#           "name": "seed",
#           "type": "INT",
#           "link": 60,
#           "widget": {
#             "name": "seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             45
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "KSampler"
#       },
#       "widgets_values": [
#         135313577566690,
#         "fixed",
#         20,
#         8,
#         "dpmpp_3m_sde",
#         "karras",
#         0.5
#       ],
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     },
#     {
#       "id": 29,
#       "type": "KSampler",
#       "pos": [
#         3040,
#         787
#       ],
#       "size": {
#         "0": 315,
#         "1": 474
#       },
#       "flags": {},
#       "order": 31,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "model",
#           "type": "MODEL",
#           "link": 50
#         },
#         {
#           "name": "positive",
#           "type": "CONDITIONING",
#           "link": 53
#         },
#         {
#           "name": "negative",
#           "type": "CONDITIONING",
#           "link": 54
#         },
#         {
#           "name": "latent_image",
#           "type": "LATENT",
#           "link": 99
#         },
#         {
#           "name": "seed",
#           "type": "INT",
#           "link": 62,
#           "widget": {
#             "name": "seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             47
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "KSampler"
#       },
#       "widgets_values": [
#         135313577566690,
#         "fixed",
#         20,
#         8,
#         "dpmpp_3m_sde",
#         "karras",
#         0.5
#       ],
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 46,
#       "type": "BNK_InjectNoise",
#       "pos": [
#         2452,
#         598
#       ],
#       "size": {
#         "0": 315,
#         "1": 98
#       },
#       "flags": {},
#       "order": 26,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "latents",
#           "type": "LATENT",
#           "link": 95
#         },
#         {
#           "name": "noise",
#           "type": "LATENT",
#           "link": null
#         },
#         {
#           "name": "mask",
#           "type": "MASK",
#           "link": null
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             100
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "BNK_InjectNoise"
#       },
#       "widgets_values": [
#         3
#       ],
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 47,
#       "type": "BNK_InjectNoise",
#       "pos": [
#         2452,
#         1258
#       ],
#       "size": {
#         "0": 315,
#         "1": 98
#       },
#       "flags": {},
#       "order": 28,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "latents",
#           "type": "LATENT",
#           "link": 97
#         },
#         {
#           "name": "noise",
#           "type": "LATENT",
#           "link": null
#         },
#         {
#           "name": "mask",
#           "type": "MASK",
#           "link": null
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             99
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "BNK_InjectNoise"
#       },
#       "widgets_values": [
#         3
#       ],
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 4,
#       "type": "CheckpointLoaderSimple",
#       "pos": [
#         37,
#         524
#       ],
#       "size": {
#         "0": 315,
#         "1": 98
#       },
#       "flags": {},
#       "order": 2,
#       "mode": 0,
#       "outputs": [
#         {
#           "name": "MODEL",
#           "type": "MODEL",
#           "links": [
#             14,
#             22,
#             36,
#             48,
#             50,
#             84
#           ],
#           "slot_index": 0
#         },
#         {
#           "name": "CLIP",
#           "type": "CLIP",
#           "links": [
#             3,
#             5
#           ],
#           "slot_index": 1
#         },
#         {
#           "name": "VAE",
#           "type": "VAE",
#           "links": [
#             8,
#             24,
#             38,
#             66,
#             88,
#             89,
#             90,
#             91,
#             92
#           ],
#           "slot_index": 2
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "CheckpointLoaderSimple"
#       },
#       "widgets_values": [
#         "Differentia_V1-00001.safetensors"
#       ]
#     },
#     {
#       "id": 20,
#       "type": "PrimitiveNode",
#       "pos": [
#         29,
#         348
#       ],
#       "size": {
#         "0": 210,
#         "1": 82
#       },
#       "flags": {},
#       "order": 3,
#       "mode": 0,
#       "outputs": [
#         {
#           "name": "INT",
#           "type": "INT",
#           "links": [
#             30,
#             31,
#             35,
#             60,
#             62,
#             81
#           ],
#           "slot_index": 0,
#           "widget": {
#             "name": "noise_seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "properties": {},
#       "widgets_values": [
#         135313577566690,
#         "fixed"
#       ]
#     },
#     {
#       "id": 19,
#       "type": "PreviewImage",
#       "pos": [
#         403,
#         1022
#       ],
#       "size": {
#         "0": 210,
#         "1": 246
#       },
#       "flags": {},
#       "order": 7,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "images",
#           "type": "IMAGE",
#           "link": 108
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "PreviewImage"
#       },
#       "color": "#323",
#       "bgcolor": "#535"
#     },
#     {
#       "id": 49,
#       "type": "WAS_PFN_Latent",
#       "pos": [
#         27,
#         893
#       ],
#       "size": {
#         "0": 315,
#         "1": 486
#       },
#       "flags": {},
#       "order": 4,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "encoding_vae",
#           "type": "VAE",
#           "link": null
#         }
#       ],
#       "outputs": [
#         {
#           "name": "latents",
#           "type": "LATENT",
#           "links": [
#             110,
#             111
#           ],
#           "shape": 3,
#           "slot_index": 0
#         },
#         {
#           "name": "previews",
#           "type": "IMAGE",
#           "links": [
#             108
#           ],
#           "shape": 3,
#           "slot_index": 1
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "WAS_PFN_Latent"
#       },
#       "widgets_values": [
#         1,
#         1024,
#         1024,
#         0,
#         0,
#         0,
#         0,
#         0,
#         5,
#         8,
#         1,
#         2,
#         4,
#         0,
#         0,
#         477331500828719,
#         "randomize",
#         "cpu"
#       ],
#       "color": "#323",
#       "bgcolor": "#535"
#     },
#     {
#       "id": 13,
#       "type": "KSamplerAdvanced",
#       "pos": [
#         876,
#         194
#       ],
#       "size": {
#         "0": 315,
#         "1": 546
#       },
#       "flags": {},
#       "order": 8,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "model",
#           "type": "MODEL",
#           "link": 14
#         },
#         {
#           "name": "positive",
#           "type": "CONDITIONING",
#           "link": 15
#         },
#         {
#           "name": "negative",
#           "type": "CONDITIONING",
#           "link": 16
#         },
#         {
#           "name": "latent_image",
#           "type": "LATENT",
#           "link": 111
#         },
#         {
#           "name": "noise_seed",
#           "type": "INT",
#           "link": 30,
#           "widget": {
#             "name": "noise_seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             18
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "title": "PPF Noise KSampler (Advanced)",
#       "properties": {
#         "Node name for S&R": "KSamplerAdvanced"
#       },
#       "widgets_values": [
#         "disable",
#         135313577566690,
#         "fixed",
#         20,
#         8,
#         "dpmpp_3m_sde",
#         "karras",
#         0,
#         10000,
#         "disable"
#       ],
#       "color": "#232",
#       "bgcolor": "#353"
#     },
#     {
#       "id": 21,
#       "type": "KSampler",
#       "pos": [
#         873,
#         787
#       ],
#       "size": {
#         "0": 315,
#         "1": 474
#       },
#       "flags": {},
#       "order": 10,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "model",
#           "type": "MODEL",
#           "link": 36
#         },
#         {
#           "name": "positive",
#           "type": "CONDITIONING",
#           "link": 32
#         },
#         {
#           "name": "negative",
#           "type": "CONDITIONING",
#           "link": 33
#         },
#         {
#           "name": "latent_image",
#           "type": "LATENT",
#           "link": 110
#         },
#         {
#           "name": "seed",
#           "type": "INT",
#           "link": 35,
#           "widget": {
#             "name": "seed",
#             "config": [
#               "INT",
#               {
#                 "default": 0,
#                 "min": 0,
#                 "max": 18446744073709552000
#               }
#             ]
#           }
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             37
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "title": "PPF Noise + Vanilla Noise KSampler",
#       "properties": {
#         "Node name for S&R": "KSampler"
#       },
#       "widgets_values": [
#         135313577566690,
#         "fixed",
#         20,
#         8,
#         "dpmpp_3m_sde",
#         "karras",
#         1
#       ],
#       "color": "#223",
#       "bgcolor": "#335"
#     },
#     {
#       "id": 34,
#       "type": "VAEEncode",
#       "pos": [
#         2200,
#         2
#       ],
#       "size": {
#         "0": 210,
#         "1": 46
#       },
#       "flags": {},
#       "order": 24,
#       "mode": 0,
#       "inputs": [
#         {
#           "name": "pixels",
#           "type": "IMAGE",
#           "link": 65
#         },
#         {
#           "name": "vae",
#           "type": "VAE",
#           "link": 66
#         }
#       ],
#       "outputs": [
#         {
#           "name": "LATENT",
#           "type": "LATENT",
#           "links": [
#             102
#           ],
#           "shape": 3,
#           "slot_index": 0
#         }
#       ],
#       "properties": {
#         "Node name for S&R": "VAEEncode"
#       },
#       "color": "#2a363b",
#       "bgcolor": "#3f5159"
#     }
#   ],
#   "links": [
#     [
#       3,
#       4,
#       1,
#       6,
#       0,
#       "CLIP"
#     ],
#     [
#       5,
#       4,
#       1,
#       7,
#       0,
#       "CLIP"
#     ],
#     [
#       8,
#       4,
#       2,
#       8,
#       1,
#       "VAE"
#     ],
#     [
#       9,
#       8,
#       0,
#       9,
#       0,
#       "IMAGE"
#     ],
#     [
#       14,
#       4,
#       0,
#       13,
#       0,
#       "MODEL"
#     ],
#     [
#       15,
#       6,
#       0,
#       13,
#       1,
#       "CONDITIONING"
#     ],
#     [
#       16,
#       7,
#       0,
#       13,
#       2,
#       "CONDITIONING"
#     ],
#     [
#       18,
#       13,
#       0,
#       8,
#       0,
#       "LATENT"
#     ],
#     [
#       19,
#       15,
#       0,
#       14,
#       3,
#       "LATENT"
#     ],
#     [
#       20,
#       6,
#       0,
#       14,
#       1,
#       "CONDITIONING"
#     ],
#     [
#       21,
#       7,
#       0,
#       14,
#       2,
#       "CONDITIONING"
#     ],
#     [
#       22,
#       4,
#       0,
#       14,
#       0,
#       "MODEL"
#     ],
#     [
#       23,
#       14,
#       0,
#       16,
#       0,
#       "LATENT"
#     ],
#     [
#       24,
#       4,
#       2,
#       16,
#       1,
#       "VAE"
#     ],
#     [
#       25,
#       16,
#       0,
#       17,
#       0,
#       "IMAGE"
#     ],
#     [
#       30,
#       20,
#       0,
#       13,
#       4,
#       "INT"
#     ],
#     [
#       31,
#       20,
#       0,
#       14,
#       4,
#       "INT"
#     ],
#     [
#       32,
#       6,
#       0,
#       21,
#       1,
#       "CONDITIONING"
#     ],
#     [
#       33,
#       7,
#       0,
#       21,
#       2,
#       "CONDITIONING"
#     ],
#     [
#       35,
#       20,
#       0,
#       21,
#       4,
#       "INT"
#     ],
#     [
#       36,
#       4,
#       0,
#       21,
#       0,
#       "MODEL"
#     ],
#     [
#       37,
#       21,
#       0,
#       23,
#       0,
#       "LATENT"
#     ],
#     [
#       38,
#       4,
#       2,
#       23,
#       1,
#       "VAE"
#     ],
#     [
#       39,
#       23,
#       0,
#       22,
#       0,
#       "IMAGE"
#     ],
#     [
#       45,
#       27,
#       0,
#       28,
#       0,
#       "LATENT"
#     ],
#     [
#       47,
#       29,
#       0,
#       30,
#       0,
#       "LATENT"
#     ],
#     [
#       48,
#       4,
#       0,
#       27,
#       0,
#       "MODEL"
#     ],
#     [
#       50,
#       4,
#       0,
#       29,
#       0,
#       "MODEL"
#     ],
#     [
#       51,
#       6,
#       0,
#       27,
#       1,
#       "CONDITIONING"
#     ],
#     [
#       53,
#       6,
#       0,
#       29,
#       1,
#       "CONDITIONING"
#     ],
#     [
#       54,
#       7,
#       0,
#       29,
#       2,
#       "CONDITIONING"
#     ],
#     [
#       56,
#       7,
#       0,
#       27,
#       2,
#       "CONDITIONING"
#     ],
#     [
#       60,
#       20,
#       0,
#       27,
#       4,
#       "INT"
#     ],
#     [
#       62,
#       20,
#       0,
#       29,
#       4,
#       "INT"
#     ],
#     [
#       63,
#       16,
#       0,
#       31,
#       1,
#       "IMAGE"
#     ],
#     [
#       64,
#       32,
#       0,
#       31,
#       0,
#       "UPSCALE_MODEL"
#     ],
#     [
#       65,
#       33,
#       0,
#       34,
#       0,
#       "IMAGE"
#     ],
#     [
#       66,
#       4,
#       2,
#       34,
#       1,
#       "VAE"
#     ],
#     [
#       68,
#       36,
#       0,
#       37,
#       0,
#       "IMAGE"
#     ],
#     [
#       69,
#       39,
#       0,
#       40,
#       0,
#       "IMAGE"
#     ],
#     [
#       70,
#       8,
#       0,
#       35,
#       1,
#       "IMAGE"
#     ],
#     [
#       71,
#       23,
#       0,
#       38,
#       1,
#       "IMAGE"
#     ],
#     [
#       72,
#       32,
#       0,
#       38,
#       0,
#       "UPSCALE_MODEL"
#     ],
#     [
#       73,
#       32,
#       0,
#       35,
#       0,
#       "UPSCALE_MODEL"
#     ],
#     [
#       76,
#       28,
#       0,
#       42,
#       0,
#       "IMAGE"
#     ],
#     [
#       77,
#       25,
#       0,
#       41,
#       0,
#       "IMAGE"
#     ],
#     [
#       78,
#       30,
#       0,
#       43,
#       0,
#       "IMAGE"
#     ],
#     [
#       79,
#       44,
#       0,
#       25,
#       0,
#       "LATENT"
#     ],
#     [
#       81,
#       20,
#       0,
#       44,
#       4,
#       "INT"
#     ],
#     [
#       82,
#       6,
#       0,
#       44,
#       1,
#       "CONDITIONING"
#     ],
#     [
#       83,
#       7,
#       0,
#       44,
#       2,
#       "CONDITIONING"
#     ],
#     [
#       84,
#       4,
#       0,
#       44,
#       0,
#       "MODEL"
#     ],
#     [
#       85,
#       31,
#       0,
#       33,
#       0,
#       "IMAGE"
#     ],
#     [
#       86,
#       35,
#       0,
#       36,
#       0,
#       "IMAGE"
#     ],
#     [
#       87,
#       38,
#       0,
#       39,
#       0,
#       "IMAGE"
#     ],
#     [
#       88,
#       4,
#       2,
#       37,
#       1,
#       "VAE"
#     ],
#     [
#       89,
#       4,
#       2,
#       40,
#       1,
#       "VAE"
#     ],
#     [
#       90,
#       4,
#       2,
#       30,
#       1,
#       "VAE"
#     ],
#     [
#       91,
#       4,
#       2,
#       25,
#       1,
#       "VAE"
#     ],
#     [
#       92,
#       4,
#       2,
#       28,
#       1,
#       "VAE"
#     ],
#     [
#       95,
#       37,
#       0,
#       46,
#       0,
#       "LATENT"
#     ],
#     [
#       97,
#       40,
#       0,
#       47,
#       0,
#       "LATENT"
#     ],
#     [
#       99,
#       47,
#       0,
#       29,
#       3,
#       "LATENT"
#     ],
#     [
#       100,
#       46,
#       0,
#       44,
#       3,
#       "LATENT"
#     ],
#     [
#       102,
#       34,
#       0,
#       27,
#       3,
#       "LATENT"
#     ],
#     [
#       108,
#       49,
#       1,
#       19,
#       0,
#       "IMAGE"
#     ],
#     [
#       110,
#       49,
#       0,
#       21,
#       3,
#       "LATENT"
#     ],
#     [
#       111,
#       49,
#       0,
#       13,
#       3,
#       "LATENT"
#     ]
#   ],
#   "groups": [],
#   "config": {},
#   "extra": {},
#   "version": 0.4
# }
